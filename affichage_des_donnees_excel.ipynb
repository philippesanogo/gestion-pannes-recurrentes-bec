# %% [markdown]
# ## Affichage de la base de données

# %%
import pandas as pd
df = pd.read_excel("gestionnaire_pannes_recurrentes_bec.xlsx", "Index")

# %%
# J'affiche notre base de données
df
# Out:
#       Ligne         Produit Simtap  nb blisters       Date  \
# 0   Bec 650  Phloroglucinol    Oui            1 2022-11-13
# 1   Bec 650  Phloroglucinol    Oui            1 2022-11-13
# 2   Bec 650  Phloroglucinol    Oui            1 2022-11-13
# 3   Bec 650  Phloroglucinol    Oui            1 2022-11-13
# 4   Bec 650  Phloroglucinol    Oui            1 2022-11-13
# 5   Bec 780     Fenofibrate    Oui            9 2022-11-13
# 6   Bec 780     Fenofibrate    Oui            9 2022-11-13
# 7   Bec 780     Fenofibrate    Oui            9 2022-11-13
# 8   Bec 780     Fenofibrate    Oui            9 2022-11-13
# 9   Bec 780     Fenofibrate    Oui            9 2022-11-13
# 10  Bec 780     Fenofibrate    Oui            9 2022-11-13
# 11  Bec 553       Zopiclone    Oui            2 2022-11-13
# 12  Bec 553       Zopiclone    Oui            2 2022-11-12
# 13  Bec 553       Zopiclone    Oui            2 2022-11-12
# 14  Bec 553       Zopiclone    Oui            2 2022-11-12
# ...

# %% [markdown]
# ## Analyse du dataframe

# %% [markdown]
# ### Combien y a-t-il de lignes et de colonnes ?

# %%
df.shape
# Out:
# (22, 8)

# %% [markdown]
# Il y 22 lignes et 8 colonnes

# %% [markdown]
# ### Récupérer le nom des colonnes

# %%
df.columns
# Out:
# Index(['Ligne', 'Produit', 'Simtap', 'nb blisters', 'Date', 'Panne',
#        'Fréquence', 'Durée'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=22, step=1)

# %% [markdown]
# ## Redéfinir l'index de la BDD

# %%
# Je remplace l'index numérique par le label "Ligne" de la colonne du même nom
df.set_index("Ligne", inplace=True)

# %%
df
# Out:
#                 Produit Simtap  nb blisters       Date                Panne  \
# Ligne
# Bec 650  Phloroglucinol    Oui            1 2022-11-13        Remplissage 1
# Bec 650  Phloroglucinol    Oui            1 2022-11-13                TE AV
# Bec 650  Phloroglucinol    Oui            1 2022-11-13         Prises étuis
# Bec 650  Phloroglucinol    Oui            1 2022-11-13        Remplissage 1
# Bec 650  Phloroglucinol    Oui            1 2022-11-13      Clapet sécurité
# Bec 780     Fenofibrate    Oui            9 2022-11-13       Prises notices
# Bec 780     Fenofibrate    Oui            9 2022-11-13  Bourrage fardeleuse
# Bec 780     Fenofibrate    Oui            9 2022-11-13                TE AV
# Bec 780     Fenofibrate    Oui            9 2022-11-13                TE AR
# Bec 780     Fenofibrate    Oui            9 2022-11-13        Remplissage 1
# Bec 780     Fenofibrate    Oui            9 2022-11-13      Clapet sécurité
# ...
