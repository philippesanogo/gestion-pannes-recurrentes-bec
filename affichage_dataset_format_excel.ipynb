# %%
import pandas as pd
df = pd.read_excel("gestionnaire_pannes_recurrentes_bec.xlsx", "Index")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_197315/353968734.py in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_excel("gestionnaire_pannes_recurrentes_bec.xlsx", "index")
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
df
# Out:
#     Unnamed: 0                                      Unnamed: 1  \
# 0          NaN  Gestionnaire des pannes récurrentes lignes BEC
# 1          NaN                                             NaN
# 2          NaN                                             NaN
# 3          NaN                                             NaN
# 4          NaN                                             NaN
# 5          NaN                                             NaN
# 6          NaN                                             NaN
# 7          NaN                                           Ligne
# 8          NaN                                             NaN
# 9          NaN                                         Produit
# 10         NaN                                             NaN
# 11         NaN                                          Simtap
# 12         NaN                                             NaN
# 13         NaN                                     nb blisters
# ...
