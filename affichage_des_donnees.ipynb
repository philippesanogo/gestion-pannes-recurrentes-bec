# %%
import pandas as pd
df = pd.read_csv("gestionnaire_pannes_recurrentes_bec - Index.csv")

# %%
df
# Out:
#       Ligne         Produit Simtap  nb blisters        Date  \
# 0   Bec 650  Phloroglucinol    Oui            1  13/11/2022
# 1   Bec 650  Phloroglucinol    Oui            1  13/11/2022
# 2   Bec 650  Phloroglucinol    Oui            1  13/11/2022
# 3   Bec 650  Phloroglucinol    Oui            1  13/11/2022
# 4   Bec 650  Phloroglucinol    Oui            1  13/11/2022
# 5   Bec 780     Fenofibrate    Oui            9  13/11/2022
# 6   Bec 780     Fenofibrate    Oui            9  13/11/2022
# 7   Bec 780     Fenofibrate    Oui            9  13/11/2022
# 8   Bec 780     Fenofibrate    Oui            9  13/11/2022
# 9   Bec 780     Fenofibrate    Oui            9  13/11/2022
# 10  Bec 780     Fenofibrate    Oui            9  13/11/2022
# 11  Bec 553       Zopiclone    Oui            2  13/11/2022
# 12  Bec 553       Zopiclone    Oui            2  12/11/2022
# 13  Bec 553       Zopiclone    Oui            2  12/11/2022
# 14  Bec 553       Zopiclone    Oui            2  12/11/2022
# ...
